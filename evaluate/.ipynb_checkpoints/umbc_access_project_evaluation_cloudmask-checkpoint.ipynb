# %% [markdown]
# <div class="alert alert-info">
# <center>
# <h1 style="font-size:22px">UMBC ACCESS Project Evaluation</h1>
# <br>
# Benjamin H.G. Marchant <br>
# benjamin.marchant@nasa.gov <br>
# marchant.benjamin01@gmail.com <br>
# </center>
# </div>

# %%
from os import path

import glob
import random
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.patches as mpatches
import numpy as np
import seaborn as sns; sns.set()

# %%
fig_style_dict = {}

fig_style_dict['fig_type'] = 'analysis'

if fig_style_dict['fig_type'] == 'talk':
    fig_style_dict['facecolor'] = '#E8E8E8'
    fig_style_dict['label_font_size'] = 18
    fig_style_dict['title_font_size'] = 22
    fig_style_dict['heatmap_annot_font_size'] = 22
else:
    fig_style_dict['facecolor'] = 'white'
    fig_style_dict['label_font_size'] = 12
    fig_style_dict['title_font_size'] = 14
    fig_style_dict['heatmap_annot_font_size'] = 14

# %%
path_to_data = '/Volumes/HD1/media/'

# %%
sample_list = glob.glob( '{}UMBC/last/prediction/*hdf5'.format(path_to_data) )

sample_list
# Out:
# ['/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_01_05.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_01_10.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_01_15.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_01_20.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_01_25.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_02_05.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_02_10.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_02_15.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_02_20.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_02_25.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_03_05.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_03_10.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_03_15.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_03_20.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_03_25.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_04_05.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_04_10.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_04_15.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_04_20.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_04_25.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_05_05.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_05_10.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_05_15.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_05_20.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_05_25.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_06_05.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_06_10.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_06_15.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_06_20.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_06_25.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_07_05.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_07_10.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_07_15.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_07_20.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_07_25.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_08_05.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_08_10.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_08_15.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_08_20.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_08_25.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_09_05.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_09_10.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_09_15.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_09_20.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_09_25.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_10_05.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_10_10.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_10_15.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_10_20.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_10_25.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_11_05.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_11_10.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_11_15.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_11_20.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_11_25.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_12_05.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_12_10.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_12_15.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_12_20.hdf5',
#  '/Volumes/HD1/media/UMBC/last/prediction/viirs_sample_2018_12_25.hdf5']

# %%
file = random.choice(sample_list)

# %%
if path.exists(file):
    with pd.HDFStore(file) as store:
        print(store.keys())
# Out:
# ['/sample']

# %%
if path.exists(file):
    with pd.HDFStore(file) as store:
        df = store['sample']

df
# Out:
#            M01       M02       M03       M04       M05       M06       M07  \
# 0     0.224367  0.210533  0.199658  0.181305  0.183484  0.154276  0.189382
# 1     0.119331  0.100139  0.080507  0.055997  0.041283  0.037285  0.032667
# 2     0.165092  0.159774  0.153717  0.136644  0.143881  0.149658  0.148999
# 3     0.201357  0.196739  0.186103  0.151358  0.168870  0.155976  0.182905
# 4     0.077108  0.067972  0.058436  0.046041  0.042183  0.042163  0.041903
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.246019  0.239941  0.232084  0.204776  0.217011  0.152617  0.219829
# 9996  0.125008  0.095301  0.068252  0.039024  0.018972  0.013275  0.008656
# 9997  0.209374  0.200977  0.193000  0.174448  0.179126  0.154796  0.181005
# 9998  0.438639  0.431382  0.419467  0.380843  0.411610  0.152417  0.424105
# 9999  0.361511  0.359732  0.353334  0.318229  0.341719  0.156336  0.350995
#
#            M08       M09       M10  ...  viirs_Cloud_Effective_Radius_37_PCL  \
# 0     0.186763  0.000660  0.173508  ...                              -9999.0
# 1     0.027129  0.002379  0.026409  ...                              -9999.0
# 2     0.136284  0.055477  0.073650  ...                              -9999.0
# 3     0.148239  0.001959  0.126428  ...                              -9999.0
# 4     0.041163  0.006577  0.038664  ...                              -9999.0
# ...        ...       ...       ...  ...                                  ...
# 9995  0.139443  0.012415  0.042822  ...                              -9999.0
# 9996  0.003638  0.000440  0.002719  ...                              -9999.0
# 9997  0.153757  0.015953  0.085225  ...                              -9999.0
# 9998  0.276686  0.004498  0.079307  ...                              -9999.0
# 9999  0.232324  0.022011  0.072530  ...                              -9999.0
#
#       viirs_Cloud_Water_Path  viirs_Cloud_Water_Path_PCL  viirs_Cloud_Mask  \
# 0                       45.0                     -9999.0               0.0
# 1                        3.0                     -9999.0               0.0
# 2                      117.0                     -9999.0               0.0
# 3                       85.0                     -9999.0               0.0
# 4                    -9999.0                     -9999.0               0.0
# ...                      ...                         ...               ...
# 9995                 -9999.0                     -9999.0               3.0
# 9996                 -9999.0                     -9999.0               3.0
# 9997                   238.0                     -9999.0               0.0
# 9998                 -9999.0                     -9999.0               3.0
# 9999                   119.0                     -9999.0               0.0
#
#       viirs_Surface                                VNP02MOD_file  \
# 0               0.0  VNP02MOD.A2018125.0924.001.2018125151254.nc
# 1               0.0  VNP02MOD.A2018125.0454.001.2018125103507.nc
# 2               0.0  VNP02MOD.A2018125.2248.001.2018126045630.nc
# 3               3.0  VNP02MOD.A2018125.1142.001.2018125164545.nc
# 4               0.0  VNP02MOD.A2018125.1100.001.2018125164345.nc
# ...             ...                                          ...
# 9995            3.0  VNP02MOD.A2018125.1142.001.2018125164545.nc
# 9996            0.0  VNP02MOD.A2018125.0236.001.2018125090849.nc
# 9997            0.0  VNP02MOD.A2018125.2248.001.2018126045630.nc
# 9998            3.0  VNP02MOD.A2018125.0630.001.2018125120626.nc
# 9999            2.0  VNP02MOD.A2018125.0954.001.2018125164549.nc
#
#                              CLDPROP_L2_VIIRS_SNPP_file  along track idx  \
# 0     CLDPROP_L2_VIIRS_SNPP.A2018125.0924.011.201923...           2906.0
# 1     CLDPROP_L2_VIIRS_SNPP.A2018125.0454.011.201923...           3077.0
# 2     CLDPROP_L2_VIIRS_SNPP.A2018125.2248.011.201923...            579.0
# 3     CLDPROP_L2_VIIRS_SNPP.A2018125.1142.011.201923...            397.0
# 4     CLDPROP_L2_VIIRS_SNPP.A2018125.1100.011.201923...           3040.0
# ...                                                 ...              ...
# 9995  CLDPROP_L2_VIIRS_SNPP.A2018125.1142.011.201923...            824.0
# 9996  CLDPROP_L2_VIIRS_SNPP.A2018125.0236.011.201923...           2463.0
# 9997  CLDPROP_L2_VIIRS_SNPP.A2018125.2248.011.201923...           1711.0
# 9998  CLDPROP_L2_VIIRS_SNPP.A2018125.0630.011.201923...           1055.0
# 9999  CLDPROP_L2_VIIRS_SNPP.A2018125.0954.011.201923...           1665.0
#
#       cross track idx  prediction
# 0              1173.0           1
# 1               722.0           2
# 2              2330.0           2
# 3              1784.0           2
# 4               859.0           2
# ...               ...         ...
# 9995            337.0           1
# 9996           2960.0           2
# 9997           2923.0           1
# 9998            787.0           1
# 9999           3119.0           2
#
# [10000 rows x 47 columns]

# %%
df.columns
# Out:
# Index(['M01', 'M02', 'M03', 'M04', 'M05', 'M06', 'M07', 'M08', 'M09', 'M10',
#        'M11', 'M12', 'M13', 'M14', 'M15', 'M16', 'latitude', 'longitude',
#        'viirs_solar_zenith', 'viirs_sensor_zenith', 'viirs_solar_azimuth',
#        'viirs_sensor_azimuth', 'viirs_Cloud_Top_Temperature',
#        'viirs_Cloud_Top_Height', 'viirs_Cloud_Top_Pressure',
#        'viirs_Cloud_Phase_Cloud_Top_Properties',
#        'viirs_Cloud_Optical_Thickness', 'viirs_Cloud_Optical_Thickness_PCL',
#        'viirs_Cloud_Optical_Thickness_16',
#        'viirs_Cloud_Optical_Thickness_16_PCL',
#        'viirs_Cloud_Optical_Thickness_37',
#        'viirs_Cloud_Optical_Thickness_37_PCL', 'viirs_Cloud_Effective_Radius',
#        'viirs_Cloud_Effective_Radius_PCL', 'viirs_Cloud_Effective_Radius_16',
#        'viirs_Cloud_Effective_Radius_16_PCL',
#        'viirs_Cloud_Effective_Radius_37',
#        'viirs_Cloud_Effective_Radius_37_PCL', 'viirs_Cloud_Water_Path',
#        'viirs_Cloud_Water_Path_PCL', 'viirs_Cloud_Mask', 'viirs_Surface',
#        'VNP02MOD_file', 'CLDPROP_L2_VIIRS_SNPP_file', 'along track idx',
#        'cross track idx', 'prediction'],
#       dtype='object')

# %%
df['viirs_Cloud_Phase_Cloud_Top_Properties'].value_counts()
# Out:
# 1.0    4717
# 0.0    3198
# 2.0    2085
# Name: viirs_Cloud_Phase_Cloud_Top_Properties, dtype: int64

# %%
df['viirs_Cloud_Mask'].value_counts()
# Out:
# 0.0    6363
# 3.0    2853
# 1.0     439
# 2.0     345
# Name: viirs_Cloud_Mask, dtype: int64

# %%
df['prediction'].value_counts()
# Out:
# 1    4148
# 2    3300
# 0    2552
# Name: prediction, dtype: int64

# %%
df_cloudy = df[ df['viirs_Cloud_Mask'] < 2]

# %%
df_cloudy['viirs_Cloud_Phase_Cloud_Top_Properties'].value_counts()
# Out:
# 1.0    4717
# 2.0    2085
# Name: viirs_Cloud_Phase_Cloud_Top_Properties, dtype: int64

# %%
df_cloudy['prediction'].value_counts()
# Out:
# 1    2841
# 2    2222
# 0    1739
# Name: prediction, dtype: int64

# %%
m1 = df['viirs_Cloud_Mask']
m2 = df['prediction']

c1 = df[ (m1 < 2) & (m2 != 0) ].shape[0]
c2 = df[ (m1 < 2) & (m2 == 0) ].shape[0]
c3 = df[ (m1 >= 2) & (m2 != 0) ].shape[0]
c4 = df[ (m1 >= 2) & (m2 == 0) ].shape[0]

# %%
tot_counts = c1 + c2 + c3 + c4

conf_arr = np.array([[ c3,   c4],
                     [  c1,  c2]])

print(conf_arr)

conf_arr = 100. * conf_arr / tot_counts

df_cm = pd.DataFrame(conf_arr, 
                  index = ['VIIRS CLDPROP Liquid', 'VIIRS CLDPROP Ice'],
                  columns = ['VIIRS ACCESS Liquid', 'VIIRS ACCESS Ice'])

fig = plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor=fig_style_dict['facecolor'], edgecolor='k')

plt.clf()

ax = fig.add_subplot(111)

ax.set_aspect(1)

res = sns.heatmap(df_cm, annot=True, vmin=0.0, vmax=100.0, fmt='.2f', cmap="YlGnBu",annot_kws={"size": fig_style_dict['heatmap_annot_font_size']},cbar=False)

plt.xticks([0.5,1.5], ['VIIRS ACCESS Cloudy', 'VIIRS ACCESS Clear'],fontsize=fig_style_dict['label_font_size'])
plt.yticks([1.5,0.5], ['VIIRS CLDPROP Cloudy','VIIRS CLDPROP Clear'],va='center',fontsize=fig_style_dict['label_font_size'])

#plt.title('Accuracy :'+str(round((c1+c4)/tot_counts,2)),fontsize=fig_style_dict['title_font_size'])

#plt.savefig("modis_deep_learning_cloud_phase_confusion_matrix_01.png", bbox_inches='tight', dpi=100)

plt.savefig('contingency_cloud_mask.png', dpi=150)

plt.show()
# Out:
# [[2385  813]
#  [5063 1739]]

# %%
m1 = df['viirs_Cloud_Phase_Cloud_Top_Properties']
m2 = df['prediction']

c1 = df[ (m1 == 1) & (m2 == 1) ].shape[0]
c2 = df[ (m1 == 1) & (m2 == 2) ].shape[0]
c3 = df[ (m1 == 2) & (m2 == 1) ].shape[0]
c4 = df[ (m1 == 2) & (m2 == 2) ].shape[0]

# %%
tot_counts = c1 + c2 + c3 + c4

conf_arr = np.array([[ c3,   c4],
                     [  c1,  c2]])

print(conf_arr)

conf_arr = 100. * conf_arr / tot_counts

df_cm = pd.DataFrame(conf_arr, 
                  index = ['VIIRS CLDPROP Liquid', 'VIIRS CLDPROP Ice'],
                  columns = ['VIIRS ACCESS Liquid', 'VIIRS ACCESS Ice'])

fig = plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor=fig_style_dict['facecolor'], edgecolor='k')

plt.clf()

ax = fig.add_subplot(111)

ax.set_aspect(1)

res = sns.heatmap(df_cm, annot=True, vmin=0.0, vmax=100.0, fmt='.2f', cmap="YlGnBu",annot_kws={"size": fig_style_dict['heatmap_annot_font_size']},cbar=False)

plt.xticks([0.5,1.5], ['VIIRS ACCESS Liquid', 'VIIRS ACCESS Ice'],fontsize=fig_style_dict['label_font_size'])
plt.yticks([1.5,0.5], ['VIIRS CLDPROP Liquid','VIIRS CLDPROP Ice'],va='center',fontsize=fig_style_dict['label_font_size'])

#plt.title('Accuracy :'+str(round((c1+c4)/tot_counts,2)),fontsize=fig_style_dict['title_font_size'])

#plt.savefig("modis_deep_learning_cloud_phase_confusion_matrix_01.png", bbox_inches='tight', dpi=100)

plt.savefig('contingency_cloud_phase.png', dpi=150)

plt.show()
# Out:
# [[ 854  702]
#  [1987 1520]]

# %%
bins = np.arange(0,80,5)

# %%
cloudy = df['viirs_sensor_zenith'][ df['prediction'] != 0 ]
#n_cloudy, bins_new, patches = plt.hist(cloudy,bins=bins)
n_cloudy, bins_new, patches = plt.hist(cloudy,bins=bins,density=True)
plt.xlabel("VIIRS Sensor Zenith", fontsize=14)
plt.savefig('cldprop_cloud_fraction.png', dpi=150)
plt.show()
plt.close()

# %%
cloudy = df['viirs_sensor_zenith'][ df['viirs_Cloud_Mask'] < 2 ]
#n_cloudy, bins_new, patches = plt.hist(cloudy,bins=bins)
n_cloudy, bins_new, patches = plt.hist(cloudy,bins=bins,density=True)
plt.xlabel("VIIRS Sensor Zenith", fontsize=14)
plt.savefig('dl_access_cloud_fraction.png', dpi=150)
plt.show()
plt.close()

# %%
cloudy = df['viirs_sensor_zenith'][ df['viirs_Cloud_Mask'] < 2 ]
n_cloudy, bins_new, patches = plt.hist(cloudy,bins=bins)
plt.close()

liq = df['viirs_sensor_zenith'][ ( df['viirs_Cloud_Mask'] < 2 ) & (df['viirs_Cloud_Phase_Cloud_Top_Properties'] == 1) ]
n_liquid, bins_new, patches = plt.hist(liq,bins=bins)
plt.close()

liquid_cloud_fraction_per_vza = [z/y for y, z in zip(n_cloudy, n_liquid)]

print(n_cloudy)
print(n_liquid)

bins=np.arange(2.5,80,5)

for i,j in zip(n_cloudy,n_liquid):
    print(i,j)

print(bins[:-1])

plt.bar(bins[:-1],liquid_cloud_fraction_per_vza,5)

#plt.plot(bins[:-1],liquid_cloud_fraction_per_vza,5)

plt.xlim(0,70)
plt.ylim(0,1)

plt.xlabel('Sensor Zenith Angle')
plt.ylabel('Liquid Cloud Fraction')

plt.show()
# Out:
# [357. 347. 367. 376. 361. 378. 361. 436. 493. 479. 600. 792. 730. 689.
#   36.]
# [243. 235. 255. 258. 244. 254. 239. 279. 360. 332. 426. 573. 501. 493.
#   25.]
# 357.0 243.0
# 347.0 235.0
# 367.0 255.0
# 376.0 258.0
# 361.0 244.0
# 378.0 254.0
# 361.0 239.0
# 436.0 279.0
# 493.0 360.0
# 479.0 332.0
# 600.0 426.0
# 792.0 573.0
# 730.0 501.0
# 689.0 493.0
# 36.0 25.0
# [ 2.5  7.5 12.5 17.5 22.5 27.5 32.5 37.5 42.5 47.5 52.5 57.5 62.5 67.5
#  72.5]

# %%
cloudy = df['viirs_sensor_zenith'][ df['viirs_Cloud_Mask'] < 2 ]
n_cloudy, bins_new, patches = plt.hist(cloudy,bins=bins)
plt.close()

liq = df['viirs_sensor_zenith'][ ( df['viirs_Cloud_Mask'] < 2 ) & (df['viirs_Cloud_Phase_Cloud_Top_Properties'] == 2) ]
n_liquid, bins_new, patches = plt.hist(liq,bins=bins)
plt.close()

ice_cloud_fraction_per_vza = [z/y for y, z in zip(n_cloudy, n_liquid)]

bins=np.arange(2.5,80,5)

#plt.bar(bins[:-1],ice_cloud_fraction_per_vza,5)

plt.plot(bins[:-1],liquid_cloud_fraction_per_vza,5)
plt.plot(bins[:-1],ice_cloud_fraction_per_vza,5)

blue_patch = mpatches.Patch(color=(0.2980392156862745, 0.4470588235294118, 0.6901960784313725), label='LIQUID')
green_patch = mpatches.Patch(color=(0.3333333333333333, 0.6588235294117647, 0.40784313725490196), label='ICE')

plt.legend(handles=[blue_patch,green_patch])

plt.xlim(0,70)
plt.ylim(0,1)

plt.xlabel('Sensor Zenith Angle')
plt.ylabel('Ice Cloud Fraction')

plt.savefig('cldprop_cloud_phase_fraction.png', dpi=150)

plt.show()
# Out:
# <ipython-input-121-9c9bffabf54a>:9: RuntimeWarning: invalid value encountered in double_scalars
#   ice_cloud_fraction_per_vza = [z/y for y, z in zip(n_cloudy, n_liquid)]

# %%
cloudy = df['viirs_sensor_zenith'][ df['prediction'] != 0 ]
n_cloudy, bins_new, patches = plt.hist(cloudy,bins=bins)
plt.close()

liq = df['viirs_sensor_zenith'][ ( df['prediction'] != 0 ) & (df['prediction'] == 1) ]
n_liquid, bins_new, patches = plt.hist(liq,bins=bins)
plt.close()

liquid_cloud_fraction_per_vza = [z/y for y, z in zip(n_cloudy, n_liquid)]

bins=np.arange(2.5,80,5)

plt.bar(bins[:-1],liquid_cloud_fraction_per_vza,5)

#plt.plot(bins[:-1],liquid_cloud_fraction_per_vza,5)

plt.xlim(0,70)
plt.ylim(0,1)

plt.xlabel('Sensor Zenith Angle')
plt.ylabel('Liquid Cloud Fraction')

plt.show()
# Out:
# <ipython-input-122-323681fb0386>:9: RuntimeWarning: invalid value encountered in double_scalars
#   liquid_cloud_fraction_per_vza = [z/y for y, z in zip(n_cloudy, n_liquid)]

# %%
cloudy = df['viirs_sensor_zenith'][ df['prediction'] != 0 ]
n_cloudy, bins_new, patches = plt.hist(cloudy,bins=bins)
plt.close()

liq = df['viirs_sensor_zenith'][ ( df['prediction'] != 0 ) & (df['prediction'] == 2) ]
n_liquid, bins_new, patches = plt.hist(liq,bins=bins)
plt.close()

liquid_cloud_fraction_per_vza = [z/y for y, z in zip(n_cloudy, n_liquid)]

bins=np.arange(2.5,80,5)

#plt.bar(bins[:-1],liquid_cloud_fraction_per_vza,5)

plt.plot(bins[:-1],liquid_cloud_fraction_per_vza,5)
plt.plot(bins[:-1],ice_cloud_fraction_per_vza,5)

plt.xlim(0,70)
plt.ylim(0,1)

blue_patch = mpatches.Patch(color=(0.2980392156862745, 0.4470588235294118, 0.6901960784313725), label='LIQUID')
green_patch = mpatches.Patch(color=(0.3333333333333333, 0.6588235294117647, 0.40784313725490196), label='ICE')

plt.legend(handles=[blue_patch,green_patch])

plt.xlabel('Sensor Zenith Angle')
plt.ylabel('Ice Cloud Fraction')

plt.savefig('dl_access_cloud_phase_fraction.png', dpi=150)

plt.show()
# Out:
# <ipython-input-123-2f064567681a>:9: RuntimeWarning: invalid value encountered in double_scalars
#   liquid_cloud_fraction_per_vza = [z/y for y, z in zip(n_cloudy, n_liquid)]
